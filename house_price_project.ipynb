# %%
import pandas as pd

# %%
df = pd.read_csv("data/house_prices_srilanka.csv")

# %%
df.head()
# Out:
#        district                 area  perch  bedrooms  bathrooms  \
# 0   Polonnaruwa  Polonnaruwa Central     14         5          4
# 1        Matale       Matale Central     26         7          5
# 2    Mullaitivu   Mullaitivu Central      7         3          2
# 3  Anuradhapura             New Town      2         2          2
# 4    Batticaloa      Batticaloa Town     20         5          4
#
#    kitchen_area_sqft  parking_spots  has_garden  has_ac water_supply  \
# 0                112              2       False   False   Pipe-borne
# 1                250              2        True   False         Both
# 2                 77              2        True    True         Well
# 3                 39              1        True    True         Both
# 4                117              1        True    True         Well
#
#     electricity  floors  year_built  price_lkr
# 0  Single phase       1        2022   16236332
# 1  Single phase       3        1987   33907509
# ...

# %%
df.shape
# Out:
# (20000, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district           20000 non-null  str
#  1   area               20000 non-null  str
#  2   perch              20000 non-null  int64
#  3   bedrooms           20000 non-null  int64
#  4   bathrooms          20000 non-null  int64
#  5   kitchen_area_sqft  20000 non-null  int64
#  6   parking_spots      20000 non-null  int64
#  7   has_garden         20000 non-null  bool
#  8   has_ac             20000 non-null  bool
#  9   water_supply       20000 non-null  str
#  10  electricity        20000 non-null  str
#  11  floors             20000 non-null  int64
#  12  year_built         20000 non-null  int64
#  13  price_lkr          20000 non-null  int64
# dtypes: bool(2), int64(8), str(4)
# memory usage: 1.9 MB

# %%
df.describe()
# Out:
#               perch      bedrooms     bathrooms  kitchen_area_sqft  \
# count  20000.000000  20000.000000  20000.000000       20000.000000
# mean      11.510500      3.901600      3.171650         113.718800
# std        8.519719      1.839426      1.530883          69.801873
# min        2.000000      1.000000      1.000000          35.000000
# 25%        5.000000      2.000000      2.000000          53.000000
# 50%       10.000000      4.000000      3.000000          95.000000
# 75%       16.000000      5.000000      5.000000         161.000000
# max       80.000000      7.000000      5.000000         250.000000
#
#        parking_spots        floors    year_built     price_lkr
# count   20000.000000  20000.000000  20000.000000  2.000000e+04
# mean        1.141100      1.557150   2004.926550  1.598142e+07
# std         0.939167      0.628135     11.817353  1.338156e+07
# min         0.000000      1.000000   1985.000000  1.500000e+06
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, KFold, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor

from sklearn.metrics import(
    mean_absolute_error,
    mean_squared_error,
    r2_score,
)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district           20000 non-null  str
#  1   area               20000 non-null  str
#  2   perch              20000 non-null  int64
#  3   bedrooms           20000 non-null  int64
#  4   bathrooms          20000 non-null  int64
#  5   kitchen_area_sqft  20000 non-null  int64
#  6   parking_spots      20000 non-null  int64
#  7   has_garden         20000 non-null  bool
#  8   has_ac             20000 non-null  bool
#  9   water_supply       20000 non-null  str
#  10  electricity        20000 non-null  str
#  11  floors             20000 non-null  int64
#  12  year_built         20000 non-null  int64
#  13  price_lkr          20000 non-null  int64
# dtypes: bool(2), int64(8), str(4)
# memory usage: 1.9 MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district           20000 non-null  str
#  1   area               20000 non-null  str
#  2   perch              20000 non-null  int64
#  3   bedrooms           20000 non-null  int64
#  4   bathrooms          20000 non-null  int64
#  5   kitchen_area_sqft  20000 non-null  int64
#  6   parking_spots      20000 non-null  int64
#  7   has_garden         20000 non-null  bool
#  8   has_ac             20000 non-null  bool
#  9   water_supply       20000 non-null  str
#  10  electricity        20000 non-null  str
#  11  floors             20000 non-null  int64
#  12  year_built         20000 non-null  int64
#  13  price_lkr          20000 non-null  int64
# dtypes: bool(2), int64(8), str(4)
# memory usage: 1.9 MB

# %%
target_col = "price_lkr"
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()

print("Numerical columns: - house_price_project.ipynb:5", num_cols)
print("Categorical columns: - house_price_project.ipynb:6", cat_cols)
print("Target column: - house_price_project.ipynb:7", target_col)
# Out:
# Numerical columns: - house_price_project.ipynb:5 ['perch', 'bedrooms', 'bathrooms', 'kitchen_area_sqft', 'parking_spots', 'floors', 'year_built', 'price_lkr']
# Categorical columns: - house_price_project.ipynb:6 ['district', 'area', 'water_supply', 'electricity']
# Target column: - house_price_project.ipynb:7 price_lkr
# C:\Users\Kavindhya\AppData\Local\Temp\ipykernel_20796\3130270943.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=["object"]).columns.tolist()

# %%
print("\nMissing values per column - house_price_project.ipynb:1")
print(df.isnull().sum())
# Out:
# Missing values per column - house_price_project.ipynb:1
# district             0
# area                 0
# perch                0
# bedrooms             0
# bathrooms            0
# kitchen_area_sqft    0
# parking_spots        0
# has_garden           0
# has_ac               0
# water_supply         0
# electricity          0
# floors               0
# year_built           0
# price_lkr            0
# dtype: int64

# %%
for col in df.columns:
    print(df[col].value_counts().head(20))
# Out:
# district
# Polonnaruwa     845
# Batticaloa      837
# Badulla         834
# Gampaha         825
# Colombo         818
# Hambantota      814
# Kegalle         810
# Kurunegala      810
# Kandy           809
# Ampara          807
# Monaragala      807
# Jaffna          802
# Kalutara        801
# Mannar          801
# Galle           801
# Puttalam        799
# Anuradhapura    790
# Matale          788
# Kilinochchi     788
# Vavuniya        782
# Name: count, dtype: int64
# area
# Polonnaruwa Central     845
# Kegalle Central         810
# Ampara Central          807
# Monaragala Central      807
# Mannar Central          801
# Puttalam Central        799
# Matale Central          788
# Kilinochchi Central     788
# Vavuniya Central        782
# Mullaitivu Central      781
# Nuwara Eliya Central    765
# Hambantota Town         297
# Bandarawela             291
# China Bay               288
# Batticaloa Town         286
# Badulla Town            281
# Kallady                 280
# ...
